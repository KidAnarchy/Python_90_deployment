# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from flask import Flask, request
from flask_cors import CORS, cross_origin

app = Flask(__name__)
CORS(app)

@app.route('/')
def helloworld():
    return 'Helloworld'

@app.route('/area')
@cross_origin()
def area():
    w = float(request.values['w'])
    h = float(request.values['h'])
    return str(w * h)

@app.route('/bmi', methods=['GET'])
@cross_origin()
def bmi():
    weight = float(request.values['weight'])
    height = float(request.values['height'])
    return str(weight / ((height/100)*(height/100)))

if __name__=='__main__':
    app.run(host='0.0.0.0', port=5000, debug=False)
    
# http://localhost:5000/area?w=10&h=20
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [10/Nov/2021 14:25:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2021 14:29:22] "GET /area?w=10&h=20 HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2021 14:31:26] "GET /bmi?w=7&h=175 HTTP/1.1" 400 -
# 127.0.0.1 - - [10/Nov/2021 14:31:47] "GET /bmi?w=7&h=1.75 HTTP/1.1" 400 -
# 127.0.0.1 - - [10/Nov/2021 14:32:51] "GET /bmi?weight=70&height=175 HTTP/1.1" 200 -

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# app = Flask(__name__)
# CORS(app)
#
# @app.route('/bmi', methods=['GET'])
# @cross_origin()
# def bmi():
#     weight = float(request.values['weight'])
#     height = float(request.values['height'])
#     return str(weight / ((height/100)*(height/100)))
#
# if __name__=='__main__':
#     app.run(host='0.0.0.0', port=5000, debug=False)

# %%
# http://localhost:5000/bmi?weight=75&height=176
